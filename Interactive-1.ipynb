# %% [markdown]
# Connected to Python 3.10.12

# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
print("x_train shape:", x_train.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# x_train shape: (60000, 28, 28)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10, activation='softmax')
])
# Out:
# /Users/paulmutawe/.pyenv/versions/3.10.12/lib/python3.10/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
r = model.fit(x_train, y_train,validation_data=(x_test, y_test), epochs = 10)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 722us/step - accuracy: 0.8518 - loss: 0.4974 - val_accuracy: 0.9560 - val_loss: 0.1475
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 798us/step - accuracy: 0.9534 - loss: 0.1544 - val_accuracy: 0.9688 - val_loss: 0.0995
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 693us/step - accuracy: 0.9657 - loss: 0.1130 - val_accuracy: 0.9718 - val_loss: 0.0872
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 700us/step - accuracy: 0.9732 - loss: 0.0865 - val_accuracy: 0.9721 - val_loss: 0.0859
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 663us/step - accuracy: 0.9770 - loss: 0.0717 - val_accuracy: 0.9775 - val_loss: 0.0737
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 668us/step - accuracy: 0.9795 - loss: 0.0646 - val_accuracy: 0.9785 - val_loss: 0.0697
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 655us/step - accuracy: 0.9811 - loss: 0.0576 - val_accuracy: 0.9791 - val_loss: 0.0670
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 674us/step - accuracy: 0.9841 - loss: 0.0492 - val_accuracy: 0.9790 - val_loss: 0.0696
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 1s 659us/step - accuracy: 0.9855 - loss: 0.0449 - val_accuracy: 0.9803 - val_loss: 0.0655
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 2s 880us/step - accuracy: 0.9865 - loss: 0.0421 - val_accuracy: 0.9815 - val_loss: 0.0695

# %%
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label = 'loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /Users/paulmutawe/Desktop/Practice/ANN_Classification.py:1
# ----> 1 import matplotlib.pyplot as plt
#       2 plt.plot(r.history['loss'], label = 'loss')
#       3 plt.plot(r.history['val_loss'], label='val_loss')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label = 'loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
plt.plot(r.history['accuracy'], label = 'acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()

# %%
print(model.evaluate(x_test, y_test))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - accuracy: 0.9786 - loss: 0.0824
# [0.06953740119934082, 0.9815000295639038]

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize: 
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arrange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 320us/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File /Users/paulmutawe/Desktop/Practice/ANN_Classification.py:20
#      17     plt.yticks(tick_marks, classes)
#      19 p_test = model.predict(x_test).argmax(axis=1)
# ---> 20 cm = confusion_matrix(y_test, p_test)
#      21 plot_confusion_matrix(cm, list(range(10)))
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import itertools
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File /Users/paulmutawe/Desktop/Practice/ANN_Classification.py:1
# ----> 1 from sklearn.metrics import confusion_matrix
#       2 import numpy as np
#       3 import itertools
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import itertools

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize: 
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arrange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 277us/step
# Confusion matrix, without normalization
# [[ 969    0    0    2    1    1    3    1    2    1]
#  [   0 1128    2    1    0    0    1    0    3    0]
#  [   2    1  999    1    4    0    1    9   15    0]
#  [   1    0    1  993    0    4    0    6    3    2]
#  [   0    0    3    1  972    0    2    1    1    2]
#  [   2    0    0    6    2  870    3    1    7    1]
#  [   3    2    2    1    4    3  939    1    3    0]
#  [   0    3    6    3    1    0    0 1012    1    2]
#  [   1    0    2    5    4    1    0    4  955    2]
#  [   1    4    0    6   12    1    0    5    2  978]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /Users/paulmutawe/Desktop/Practice/ANN_Classification.py:21
#      19 p_test = model.predict(x_test).argmax(axis=1)
#      20 cm = confusion_matrix(y_test, p_test)
# ---> 21 plot_confusion_matrix(cm, list(range(10)))
#
# File /Users/paulmutawe/Desktop/Practice/ANN_Classification.py:15
#      13 plt.title(title)
#      14 plt.colorbar()
# ---> 15 tick_marks = np.arrange(len(classes))
#      16 plt.xticks(tick_marks, classes, rotation=45)
#      17 plt.yticks(tick_marks, classes)
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/site-packages/numpy/__init__.py:410, in __getattr__(attr)
#     407     import numpy.char as char
#     408     return char.chararray
# --> 410 raise AttributeError("module {!r} has no attribute "
#     411                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'arrange'

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize: 
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step
# Confusion matrix, without normalization
# [[ 969    0    0    2    1    1    3    1    2    1]
#  [   0 1128    2    1    0    0    1    0    3    0]
#  [   2    1  999    1    4    0    1    9   15    0]
#  [   1    0    1  993    0    4    0    6    3    2]
#  [   0    0    3    1  972    0    2    1    1    2]
#  [   2    0    0    6    2  870    3    1    7    1]
#  [   3    2    2    1    4    3  939    1    3    0]
#  [   0    3    6    3    1    0    0 1012    1    2]
#  [   1    0    2    5    4    1    0    4  955    2]
#  [   1    4    0    6   12    1    0    5    2  978]]

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize: 
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    print(cm)

    plt.matshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step
# Confusion matrix, without normalization
# [[ 967    0    2    1    1    3    3    1    2    0]
#  [   0 1127    4    0    0    0    2    0    2    0]
#  [   1    0 1005    4    2    1    1    6   11    1]
#  [   0    0    1  998    0    3    0    6    2    0]
#  [   0    0    6    0  963    0    1    0    2   10]
#  [   1    0    0   14    2  863    3    2    6    1]
#  [   4    3    2    1    2   10  934    0    2    0]
#  [   0    4    9    3    0    0    0 1008    0    4]
#  [   3    0    2    9    4    2    4    7  941    2]
#  [   1    5    0   11    8    5    0    8    4  967]]

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize: 
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    print(cm)

    plt.matshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range (cm.shape[1])):
        plt.text(j, i, format(cm[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
        plt.tight_layout()

p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 281us/step
# Confusion matrix, without normalization
# [[ 967    0    2    1    1    3    3    1    2    0]
#  [   0 1127    4    0    0    0    2    0    2    0]
#  [   1    0 1005    4    2    1    1    6   11    1]
#  [   0    0    1  998    0    3    0    6    2    0]
#  [   0    0    6    0  963    0    1    0    2   10]
#  [   1    0    0   14    2  863    3    2    6    1]
#  [   4    3    2    1    2   10  934    0    2    0]
#  [   0    4    9    3    0    0    0 1008    0    4]
#  [   3    0    2    9    4    2    4    7  941    2]
#  [   1    5    0   11    8    5    0    8    4  967]]
# <ipython-input-17-d58366fb1355>:31: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
from sklearn.metrics import confusion_matrix
import numpy as np
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='confusion matrix',
                          cmap=plt.cm.Blues):
    if normalize: 
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')
    print(cm)

    plt.matshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    thresh = cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range (cm.shape[1])):
        plt.text(j, i, format(cm[i, j], 'd'),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
        
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
        plt.tight_layout()

p_test = model.predict(x_test).argmax(axis=1)
cm = confusion_matrix(y_test, p_test)
plot_confusion_matrix(cm, list(range(10)))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 282us/step
# Confusion matrix, without normalization
# [[ 967    0    2    1    1    3    3    1    2    0]
#  [   0 1127    4    0    0    0    2    0    2    0]
#  [   1    0 1005    4    2    1    1    6   11    1]
#  [   0    0    1  998    0    3    0    6    2    0]
#  [   0    0    6    0  963    0    1    0    2   10]
#  [   1    0    0   14    2  863    3    2    6    1]
#  [   4    3    2    1    2   10  934    0    2    0]
#  [   0    4    9    3    0    0    0 1008    0    4]
#  [   3    0    2    9    4    2    4    7  941    2]
#  [   1    5    0   11    8    5    0    8    4  967]]
# <ipython-input-18-d58366fb1355>:31: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
